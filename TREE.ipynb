# %% [markdown]
# # Tree

# %% [markdown]
# ## Implementation of binary search tree with INORDER

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def InorderTraversal(self,root):
    if root is None:
      return
    self.InorderTraversal(root.left)
    print(f"{root.data} ->",end=" ")
    self.InorderTraversal(root.right)


obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
obj.InorderTraversal(obj.root)
# Out:
# 50
# 30
# 70
# 20
# 40
# 60
# 90
# -65
# 20 -> 30 -> 40 -> 50 -> 60 -> 70 -> 90 ->

# %% [markdown]
# # HOMEWORK

# %% [markdown]
# ## Secret sharing(2327)

# %%
class Solution:
    def peopleAwareOfSecret(self, n: int, delay: int, forget: int) -> int:
        MOD = 10**9 + 7
        # dp[i]: Number of people who learn the secret on day i (1-indexed)
        dp = [0] * (n + 1)
        dp[1] = 1  # Day 1: one person learns the secret

        # total_sharers: Count of people currently able to share the secret
        total_sharers = 0
        answer = 0

        for day in range(2, n + 1):
            # If day > delay: those who learned on day - delay start sharing today
            if day - delay >= 1:
                total_sharers = (total_sharers + dp[day - delay]) % MOD
            # If day > forget: those who learned on day - forget forget today
            if day - forget >= 1:
                total_sharers = (total_sharers - dp[day - forget] + MOD) % MOD

            dp[day] = total_sharers

        # Sum up people who still remember the secret on day n:
        for day in range(n - forget + 1, n + 1):
            if day >= 1:
                answer = (answer + dp[day]) % MOD

        return answer
obj=Solution()
obj.peopleAwareOfSecret(6,2,4)
# Out:
# 5

# %% [markdown]
# ## Count partitions(3578)

# %%
from bisect import bisect_left, insort
from typing import List

class Solution:
    def countPartitions(self, nums: List[int], k: int) -> int:
        MOD = 10**9 + 7

        class SortedList:
            """Simple sorted list to maintain a sliding window."""
            def __init__(self):
                self.data = []

            def add(self, x: int):
                insort(self.data, x)

            def remove(self, x: int):
                idx = bisect_left(self.data, x)
                if idx < len(self.data) and self.data[idx] == x:
                    self.data.pop(idx)

            def get_min(self) -> int:
                return self.data[0] if self.data else float('inf')

            def get_max(self) -> int:
                return self.data[-1] if self.data else float('-inf')

        n = len(nums)
        dp = [0] * (n + 1)   # dp[i]: number of ways to partition first i elements
        prefix_sum = [0] * (n + 1)
        dp[0] = 1           # Base case: empty partition
        prefix_sum[0] = 1

        window = SortedList()
        left = 1  # 1-based index for left boundary of valid window

        for right in range(1, n + 1):
            window.add(nums[right - 1])

            # Shrink window until max-min ≤ k
            while window.get_max() - window.get_min() > k:
                window.remove(nums[left - 1])
                left += 1

            # Calculate dp[right]
            # Ways to partition ending at right = sum(dp[l - 1] ... dp[right - 1])
            sum_before_left = prefix_sum[left - 2] if left >= 2 else 0
            dp[right] = (prefix_sum[right - 1] - sum_before_left + MOD) % MOD
            prefix_sum[right] = (prefix_sum[right - 1] + dp[right]) % MOD

        return dp[n]

obj=Solution()
obj.countPartitions([9,4,1,3,7],4)
# Out:
# 6

# %% [markdown]
# # HOMEWORK END

# %% [markdown]
# # IMPLEMENTATION OF BREADTH FIRST SEARCH

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def bfs(self):
    que=deque()
    que.append(self.root)
    while que:
      temp=que.popleft()
      print(temp.data,end=" ")
      if temp.left:
        que.append(temp.left)
      if temp.right:
        que.append(temp.right)



obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
obj.bfs()
# Out:
# 50
# 70
# 30
# -5
# 50 30 70

# %% [markdown]
# # HEIGHT OF A TREE

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def treeheight(self,root):
    if root is None:
      return 0
    lheight=self.treeheight(root.left)
    rheight=self.treeheight(root.right)
    return max(lheight,rheight)+1



obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
h=obj.treeheight(obj.root)
print(f"HEIGHT = {h}")
# Out:
# 50
# 30
# 70
# 20
# 40
# 60
# 90
# 25
# 35
# 85
# 23
# 24
# -1
# HEIGHT = 6

# %% [markdown]
# # FINDING LEAST COMMON ANCESTOR

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def leastCommonAncestor(self,n1,n2):
    temp=self.root
    if temp==None:
      return -1
    while temp:
      if n1<temp.data and n2<temp.data:
        temp=temp.left
      elif n1>temp.data and n2>temp.data:
        temp=temp.right
      elif (n1>temp.data and n2<temp.data) and (n1<temp.data and n2>temp.data) :
        return temp.data
      elif n1==temp.data or n2==temp.data:
        return temp.data
      else:
        return -1
    return -1




obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
n1=int(input("n1="))
n2=int(input("n2="))
h=obj.leastCommonAncestor(n1,n2)
print(f"Least Common Ancestor = {h}")
# Out:
# 50
# 20
# 30
# 60
# 70
# -1
# n1=20
# n2=60
# Least Common Ancestor = -1

# %% [markdown]
# # SUM OF NODES HAVING SINGLE CHILD

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break
  def bfs(self):
    que=deque()
    que.append(self.root)
    sum_nodes=0
    while que:
      temp=que.popleft()
      if (temp.left!=None and temp.right==None) or (temp.left==None and temp.right!=None):
        sum_nodes += temp.data
      if temp.left:
        que.append(temp.left)
      if temp.right:
        que.append(temp.right)
    return sum_nodes
'''
  def sum_single_child_nodes(self, root):
    if root is None:
      return 0
    sum_nodes = 0
    if (root.left and not root.right) or (not root.left and root.right):
      sum_nodes += root.data
    sum_nodes += self.sum_single_child_nodes(root.left)
    sum_nodes += self.sum_single_child_nodes(root.right)
    return sum_nodes
'''


obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
single=obj.bfs()
print("\nSUM OF NODES HAVING SINGLE CHILD:")
#single_child_sum = obj.sum_single_child_nodes(obj.root)
print(single)
# Out:
# 50
# 20
# 60
# 30
# 70
# -1
#
# SUM OF NODES HAVING SINGLE CHILD:
# 80

# %% [markdown]
# # DELETE NODES WITH SINGLE CHILD

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def deleteSingleparent(self):
    que=deque()
    que.append([self.root,None])
    while que:
      curr,parent=que.popleft()

      if (curr.left!=None and curr.right==None) or (curr.left==None and curr.right!=None):
        child=None
        if curr.left:
          child=curr.left
        else:
          child=curr.right
        if parent==None:
          self.root=child
        elif parent.left==curr:
          parent.left=child
        else:
          parent.right=child

      if curr.left:
        que.append([curr.left,curr])
      if curr.right:
        que.append([curr.right,curr])
    return self.root.data


  def bfs(self):
    que=deque()
    que.append(self.root)
    while que:
      temp=que.popleft()
      print(temp.data,end=" ")
      if temp.left:
        que.append(temp.left)
      if temp.right:
        que.append(temp.right)



obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
print("BEFORE DELETION:")
obj.bfs()
print()
obj.deleteSingleparent()
print("AFTER DELETION:")
obj.bfs()
# Out:
# 50
# 30
# 24
# 40
# 70
# 35
# 37
# -1
# BEFORE DELETION:
# 50 30 70 24 40 35 37
# AFTER DELETION:
# 50 30 70 24 35 37

# %% [markdown]
# # NODE SUM IS TARGET

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def InorderTraversal(self,root, result_list):
    if root is None:
      return
    self.InorderTraversal(root.left, result_list)
    result_list.append(root.data)
    self.InorderTraversal(root.right, result_list)

  def targetsum(self, list, target):
    for i in range(len(list)):
      for j in range(i+1,len(list)):
        if list[i]+list[j]==target:
          return list[i],list[j]
    return False



obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)

list = []
obj.InorderTraversal(obj.root,list)
print(list)
target=int(input("target="))
a,b=obj.targetsum(list,target)
print(a,b)
# Out:
# 50
# 30
# 70
# 20
# -2
# [20, 30, 50, 70]
# target=80
# 30 50

# %% [markdown]
# # K TH SMALLEST ON LEFT AND RIGHT SUBTREE

# %%
from collections import deque

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class Tree:
    def __init__(self):
        self.root = None

    def append(self, data):
        newnode = Node(data)
        if self.root is None:
            self.root = newnode
        else:
            temp = self.root
            while True:
                if data < temp.data:
                    if temp.left is not None:
                        temp = temp.left
                    else:
                        temp.left = newnode
                        break
                else:
                    if temp.right is not None:
                        temp = temp.right
                    else:
                        temp.right = newnode
                        break

    def treeheight(self, root):
        if root is None:
            return 0
        lheight = self.treeheight(root.left)
        rheight = self.treeheight(root.right)
        return max(lheight, rheight) + 1

    def kth_smallest(self, root, k):

        stack = []
        current = root
        count = 0

        while True:
            while current:
                stack.append(current)
                current = current.left

            if not stack:
                return None  # k is larger than the size of the subtree

            current = stack.pop()
            count += 1
            if count == k:
                return current.data

            current = current.right

    def kth_smallest_subtrees(self, k):
        if self.root is None:
            print("Tree is empty")
            return

        left_result = self.kth_smallest(self.root.left, k) if self.root.left else None
        right_result = self.kth_smallest(self.root.right, k) if self.root.right else None

        print(f"{k}-th smallest in LEFT subtree: {left_result}")
        print(f"{k}-th smallest in RIGHT subtree: {right_result}")



obj = Tree()
while True:
    data = int(input("Enter value (-1 to stop): "))
    if data <= 0:
        break
    obj.append(data)

h = obj.treeheight(obj.root)
print(f"HEIGHT = {h}")

k = int(input("Enter k: "))
obj.kth_smallest_subtrees(k)
# Out:
# Enter value (-1 to stop): 50
# Enter value (-1 to stop): 30
# Enter value (-1 to stop): 70
# Enter value (-1 to stop): 20
# Enter value (-1 to stop): 40
# Enter value (-1 to stop): 60
# Enter value (-1 to stop): 90
# Enter value (-1 to stop): 35
# Enter value (-1 to stop): 80
# Enter value (-1 to stop): 36
# Enter value (-1 to stop): -1
# HEIGHT = 5
# Enter k: 2
# 2-th smallest in LEFT subtree: 30
# 2-th smallest in RIGHT subtree: 70

# %% [markdown]
# # HOMEWORK

# %% [markdown]
# ## Deletion when Multiple single child in same hierarchy

# %%
from collections import deque
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def deleteSingleparent(self):
    que = deque()
    que.append([self.root, None])
    while que:
        curr, parent = que.popleft()


        if (curr.left and not curr.right) or (not curr.left and curr.right):
            child = curr.left if curr.left else curr.right
            if parent is None:
                self.root = child
            elif parent.left == curr:
                parent.left = child
            else:
                parent.right = child

            if child:
                que.append([child, parent])
        else:
            if curr.left:
                que.append([curr.left, curr])
            if curr.right:
                que.append([curr.right, curr])
  23def bfs(self):
    que=deque()
    que.append(self.root)
    while que:
      temp=que.popleft()
      if temp: # Add check for None node
        print(temp.data,end=" ")
        if temp.left:
          que.append(temp.left)
        if temp.right:
          que.append(temp.right)



obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
print("BEFORE DELETION:")
obj.bfs()
print()
obj.deleteSingleparent()
print("AFTER DELETION:")
obj.bfs()
# Out:
# 50
# 30
# 70
# 20
# 40
# 35
# 36
# -1
# BEFORE DELETION:
# 50 30 70 20 40 35 36
# AFTER DELETION:
# 50 30 70 20 36

# %% [markdown]
# ## Distance between nodes

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class Tree:
    def __init__(self):
        self.root = None

    def append(self, data):
        newnode = Node(data)
        if self.root is None:
            self.root = newnode
        else:
            temp = self.root
            while True:
                if data < temp.data:
                    if temp.left is not None:
                        temp = temp.left
                    else:
                        temp.left = newnode
                        break
                else:
                    if temp.right is not None:
                        temp = temp.right
                    else:
                        temp.right = newnode
                        break

    def find_LCA(self, root, n1, n2):

        while root:
            if n1 < root.data and n2 < root.data:
                root = root.left
            elif n1 > root.data and n2 > root.data:
                root = root.right
            else:
                return root
        return None

    def distance_from_root(self, root, val):

        distance = 0
        while root and root.data != val:
            if val < root.data:
                root = root.left
            else:
                root = root.right
            distance += 1
        return distance

    def distance_between_nodes(self, n1, n2):

        lca = self.find_LCA(self.root, n1, n2)
        if not lca:
            return -1
        d1 = self.distance_from_root(lca, n1)
        d2 = self.distance_from_root(lca, n2)
        return d1 + d2



obj = Tree()
while True:
    data = int(input("Enter value (-1 to stop): "))
    if data <= 0:
        break
    obj.append(data)

n1 = int(input("Enter first node: "))
n2 = int(input("Enter second node: "))

distance = obj.distance_between_nodes(n1, n2)
print(f"Distance between {n1} and {n2} is {distance}")
# Out:
# Enter value (-1 to stop): 50
# Enter value (-1 to stop): 30
# Enter value (-1 to stop): 70
# Enter value (-1 to stop): 20
# Enter value (-1 to stop): 40
# Enter value (-1 to stop): 60
# Enter value (-1 to stop): 90
# Enter value (-1 to stop): 35
# Enter value (-1 to stop): -1
# Enter first node: 20
# Enter second node: 35
# Distance between 20 and 35 is 3
# 3

# %% [markdown]
# ## Mirror of BST

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class Tree:
    def __init__(self):
        self.root = None

    def append(self, data):
        newnode = Node(data)
        if self.root is None:
            self.root = newnode
        else:
            temp = self.root
            while True:
                if data < temp.data:
                    if temp.left is not None:
                        temp = temp.left
                    else:
                        temp.left = newnode
                        break
                else:
                    if temp.right is not None:
                        temp = temp.right
                    else:
                        temp.right = newnode
                        break

    def mirror(self, node):
        if node is None:
            return

        node.left, node.right = node.right, node.left

        self.mirror(node.left)
        self.mirror(node.right)

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.data, end=" ")
            self.inorder(node.right)


tree = Tree()
while True:
    data = int(input("Enter node value (-1 to stop): "))
    if data == -1:
        break
    tree.append(data)

print("Original BST (inorder):")
tree.inorder(tree.root)

tree.mirror(tree.root)

print("\nMirrored BST (inorder):")
tree.inorder(tree.root)
# Out:
# Enter node value (-1 to stop): 50
# Enter node value (-1 to stop): 30
# Enter node value (-1 to stop): 70
# Enter node value (-1 to stop): 20
# Enter node value (-1 to stop): 40
# Enter node value (-1 to stop): 60
# Enter node value (-1 to stop): 90
# Enter node value (-1 to stop): -1
# Original BST (inorder):
# 20 30 40 50 60 70 90
# Mirrored BST (inorder):
# 90 70 60 50 40 30 20

# %% [markdown]
# # END OF HOMEWORK

# %% [markdown]
# # VERTICAL ORDER TRAVERSAL

# %%
from collections import deque
from collections import defaultdict
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None
class Tree:
  def __init__(self):
    self.root = None
  def append(self,data):
    newnode=Node(data)
    if self.root is None:
      self.root=newnode
    else:
      temp=self.root
      while True:
        if data<temp.data:
          if temp.left!=None:
            temp=temp.left
          else:
            temp.left=newnode
            break
        else:
          if temp.right!=None:
            temp=temp.right
          else:
            temp.right=newnode
            break


  def verticalTraversal(self):
    que=deque()
    que.append([self.root,0])
    result=defaultdict(list)
    while que:
      currnode,Hd=que.popleft()
      result[Hd].append(currnode.data)
      if currnode.left:
        que.append([currnode.left,Hd-1])
      if currnode.right:
        que.append([currnode.right,Hd+1])
    for Hd in sorted(result.keys()):
      print(f"{Hd}->{result[Hd]}")


obj=Tree()
while True:
  data=int(input())
  if data<=0:
    break
  obj.append(data)
obj.verticalTraversal()
# Out:
# 100
# 50
# 150
# 30
# 70
# 130
# 170
# -1
# -2->[30]
# -1->[50]
# 0->[100, 70, 130]
# 1->[150]
# 2->[170]
